# %% [markdown]
# # Deliverable 1 - Create a CSV File Weather Database

# %% [markdown]
# # 1 Import Dependencies

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import weather_api_key
from config import google_api_key

# %%
# Import the requests library.
import requests

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# # 2 Generate a List of Random Cities

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# # Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# krasnoselkup ru
# ipixuna br
# cape town za
# norman wells ca
# verkh-chebula ru
# paidha ug
# chokurdakh ru
# vaini to
# barrow us
# progress us
# muisne ec
# tres palos mx
# port augusta au
# butaritari ki
# punta arenas cl
# yellowknife ca
# comodoro rivadavia ar
# sorong id
# punta arenas cl
# puerto ayora ec
# rikitea pf
# rikitea pf
# rikitea pf
# rungata ki
# iqaluit ca
# busselton au
# katsuura jp
# mataura pf
# lebu cl
# fallon us
# butaritari ki
# clyde river ca
# aksarayskiy ru
# hasaki jp
# half moon bay us
# jiuquan cn
# chokurdakh ru
# avarua ck
# yellowknife ca
# vostok ru
# mataura pf
# pinczow pl
# havoysund no
# necochea ar
# taksimo ru
# adrar dz
# ekhinos gr
# cockburn town tc
# severo-kurilsk ru
# erandio es
# airai pw
# saskylakh ru
# samusu ws
# amderma ru
# geraldton au
# bengkulu id
# pevek ru
# busselton au
# lolua tv
# asau tv
# eureka us
# new norfolk au
# new norfolk au
# yellowknife ca
# illoqqortoormiut gl
# mabaruma gy
# cape town za
# yellowknife ca
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %% [markdown]
# # 3  Build Database of City Weather Data
# 2.1 Empty List to Hold the Weather Data.
#
# 2.2 Initialize Counters and Create.
#
# 2.3 Loop through the cities list.
#
# 2.4 Group the cities in sets of 50 to log the process as we find the weather data for each city.
#
# 2.5 Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
#
# 2.6 Build the city_url or endpoint for each city.
#
# 2.7 Parse the JSON weather data for the following:
#
# - City, country, and date
# - Latitude and longitude
# - Maximum temperature
# - Humidity
# - Cloudiness
# - Wind speed
# 2.8 Log the URL and the record and set numbers.
#
# 2.9 Make an API request for each city.
#
# 2.10 Add the data to a list in a dictionary format

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | krasnoselkup
# Processing Record 2 of Set 1 | ipixuna
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | norman wells
# Processing Record 5 of Set 1 | verkh-chebula
# Processing Record 6 of Set 1 | paidha
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | progress
# Processing Record 11 of Set 1 | muisne
# Processing Record 12 of Set 1 | tres palos
# Processing Record 13 of Set 1 | port augusta
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | comodoro rivadavia
# Processing Record 18 of Set 1 | sorong
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | rungata
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Krasnoselkup  65.7000   82.4667    -41.21        98          27
# 1        Ipixuna  -1.7625  -48.8043     87.75        86         100
# 2      Cape Town -33.9258   18.4232     82.11        60           0
# 3   Norman Wells  65.2820 -126.8329     -0.36        85          90
# 4  Verkh-Chebula  56.0308   87.6218    -11.09       100          96
# 5         Paidha   2.4167   30.9855     73.47        55          92
# 6     Chokurdakh  70.6333  147.9167    -23.01        99         100
# 7          Vaini -21.2000 -175.2000     78.96        94          20
# 8         Barrow  71.2906 -156.7887     -9.38        70           1
# 9       Progress  40.2851  -76.8314     39.24        65          90
#
#    Wind Speed Country Current Description                 Date
# 0        4.25      RU    scattered clouds  2021-12-19 15:22:47
# 1        3.94      BR          light rain  2021-12-19 15:22:47
# ...

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0   Krasnoselkup      RU  2021-12-19 15:22:47  65.7000   82.4667    -41.21
# 1        Ipixuna      BR  2021-12-19 15:22:47  -1.7625  -48.8043     87.75
# 2      Cape Town      ZA  2021-12-19 15:22:48 -33.9258   18.4232     82.11
# 3   Norman Wells      CA  2021-12-19 15:22:48  65.2820 -126.8329     -0.36
# 4  Verkh-Chebula      RU  2021-12-19 15:22:49  56.0308   87.6218    -11.09
# 5         Paidha      UG  2021-12-19 15:22:49   2.4167   30.9855     73.47
# 6     Chokurdakh      RU  2021-12-19 15:22:50  70.6333  147.9167    -23.01
# 7          Vaini      TO  2021-12-19 15:22:50 -21.2000 -175.2000     78.96
# 8         Barrow      US  2021-12-19 15:22:51  71.2906 -156.7887     -9.38
# 9       Progress      US  2021-12-19 15:22:51  40.2851  -76.8314     39.24
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        98          27        4.25    scattered clouds
# ...

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
